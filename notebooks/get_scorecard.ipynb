# %% [markdown]
# ## **GET UFC SCORECARD**

# %%
import requests
# Out:
# /Users/nathan.lam/Desktop/self/fightwise/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import requests

data = requests.get(
    "https://site.api.espn.com/apis/site/v2/sports/mma/ufc/scoreboard"
).json()

for event in data["events"]:
    print(f"\n{event['name']}")

    for competition in event["competitions"]:
        fighters = competition["competitors"]

        red_corner = fighters[0]["athlete"]["displayName"]
        blue_corner = fighters[1]["athlete"]["displayName"]

        status = competition["status"]["type"]["description"]

        print(f"{red_corner} vs {blue_corner}")
        print(f"Status: {status}")
# Out:
# UFC 329: McGregor vs. Holloway 2
# Cody Durden vs Alessandro Costa
# Status: Scheduled
# Zachary Reese vs Ryan Gandra
# Status: Scheduled
# Ethyn Ewing vs Farid Basharat
# Status: Scheduled
# Cesar Almeida vs Damian Pinas
# Status: Scheduled
# Wang Cong vs Tracy Cortez
# Status: Scheduled
# Kai Kamaka III vs Luke Riley
# Status: Scheduled
# Cody Garbrandt vs Adrian Yanez
# Status: Scheduled
# Gable Steveson vs Elisha Ellison
# Status: Scheduled
# Robert Whittaker vs Nikita Krylov
# Status: Scheduled
# King Green vs Terrance McKinney
# Status: Scheduled
# Brandon Royval vs Lone'er Kavanagh
# Status: Scheduled
# Cory Sandhagen vs Mario Bautista
# Status: Scheduled
# Paddy Pimblett vs Benoît Saint Denis
# Status: Scheduled
# Max Holloway vs Conor McGregor
# Status: Scheduled

# %%
data["events"][0]
# Out:
# {'id': '600059148',
#  'uid': 's:3301~l:3321~e:600059148',
#  'date': '2026-07-11T21:00Z',
#  'name': 'UFC 329: McGregor vs. Holloway 2',
#  'shortName': 'UFC 329',
#  'season': {'year': 2026, 'type': 2, 'slug': 'regular-season'},
#  'competitions': [{'id': '401883599',
#    'uid': 's:3301~l:3321~e:600059148~c:401883599',
#    'date': '2026-07-11T21:00Z',
#    'endDate': '2026-07-11T21:00Z',
#    'type': {'id': '956', 'abbreviation': 'Flyweight'},
#    'timeValid': True,
#    'neutralSite': False,
#    'playByPlayAvailable': False,
#    'recent': False,
#    'venue': {'id': '5060',
#     'fullName': 'T-Mobile Arena',
#     'address': {'city': 'Las Vegas',
#      'state': 'NV',
#      'address1': '3780 South Las Vegas Boulevard',
#      'country': 'USA'},
#     'indoor': True},
#    'competitors': [{'id': '4686725',
#      'uid': 's:3301~a:4686725',
#      'type': 'athlete',
#      'order': 2,
#      'winner': False,
#      'athlete': {'fullName': 'Cody Durden',
# ...

# %%
fighter = data["events"][0]["competitions"][-1]["competitors"][0]

# %%
competition = data["events"][0]["competitions"][-1]

# %%
competition["type"]["abbreviation"]
# Out:
# 'Welterweight'

# %%
resp = requests.get(
    f"https://site.web.api.espn.com/apis/common/v3/sports/mma/ufc/athletes/5214652/overview"
)

# %%
resp.json()
# Out:
# {'news': [{'headline': "Heavyweight burning questions: Is Hokit's rise based on substance or shtick?",
#    'lastModified': '2026-04-22T14:08:15.000+00:00',
#    'root': 'mma',
#    'premium': False,
#    'links': {'api': {'self': {'href': 'https://content.core.api.espn.com/v1/sports/news/48551698'}},
#     'mobile': {'href': 'http://m.espn.go.com/extra/mma/story?storyId=48551698'},
#     'web': {'href': 'https://www.espn.com/mma/story/_/id/48551698/heavyweight-mma-burning-questions-josh-hokit-rise-based-substance-shtick-gable-steveson-francis-ngannou'}},
#    'type': 'Story',
#    'section': 'MMA',
#    'id': 48551698,
#    'linkText': 'Heavyweight burning question: Tom Aspinall vs. Francis Ngannou?',
#    'categorized': '2026-06-28T03:31:36Z',
#    'description': "Curtis Blaydes vs. Josh Hokit restored the feeling around heavyweight MMA, but is Hokit's run sustainable?",
#    'nowId': '1-48551698',
#    'allowComments': True,
#    'images': [{'width': 1296,
#      'height': 729,
# ...

# %%
import requests

data = requests.get(
    "https://site.api.espn.com/apis/site/v2/sports/mma/ufc/scoreboard",
).json()

# %%
data["events"][0]
# Out:
# {'id': '600059148',
#  'uid': 's:3301~l:3321~e:600059148',
#  'date': '2026-07-11T21:00Z',
#  'name': 'UFC 329: McGregor vs. Holloway 2',
#  'shortName': 'UFC 329',
#  'season': {'year': 2026, 'type': 2, 'slug': 'regular-season'},
#  'competitions': [{'id': '401883599',
#    'uid': 's:3301~l:3321~e:600059148~c:401883599',
#    'date': '2026-07-11T21:00Z',
#    'endDate': '2026-07-11T21:00Z',
#    'type': {'id': '956', 'abbreviation': 'Flyweight'},
#    'timeValid': True,
#    'neutralSite': False,
#    'playByPlayAvailable': False,
#    'recent': False,
#    'venue': {'id': '5060',
#     'fullName': 'T-Mobile Arena',
#     'address': {'city': 'Las Vegas',
#      'state': 'NV',
#      'address1': '3780 South Las Vegas Boulevard',
#      'country': 'USA'},
#     'indoor': True},
#    'competitors': [{'id': '4686725',
#      'uid': 's:3301~a:4686725',
#      'type': 'athlete',
#      'order': 2,
#      'winner': False,
#      'athlete': {'fullName': 'Cody Durden',
# ...

# %%
data["events"][0]["competitions"][-1]
# Out:
# {'id': '401867788',
#  'uid': 's:3301~l:3321~e:600059148~c:401867788',
#  'date': '2026-07-12T01:00Z',
#  'endDate': '2026-07-12T01:00Z',
#  'type': {'id': '969', 'abbreviation': 'Welterweight'},
#  'timeValid': True,
#  'neutralSite': False,
#  'playByPlayAvailable': False,
#  'recent': False,
#  'venue': {'id': '5060',
#   'fullName': 'T-Mobile Arena',
#   'address': {'city': 'Las Vegas',
#    'state': 'NV',
#    'address1': '3780 South Las Vegas Boulevard',
#    'country': 'USA'},
#   'indoor': True},
#  'competitors': [{'id': '2614933',
#    'uid': 's:3301~a:2614933',
#    'type': 'athlete',
#    'order': 2,
#    'winner': False,
#    'athlete': {'fullName': 'Max Holloway',
#     'displayName': 'Max Holloway',
#     'shortName': 'M. Holloway',
#     'links': [{'language': 'en-US',
#       'rel': ['playercard', 'desktop', 'athlete'],
#       'href': 'https://www.espn.com/mma/fighter/_/id/2614933/max-holloway',
#       'text': 'Player Card',
#       'shortText': 'Player Card',
# ...

# %% [markdown]
# competition_id = "401234567"
#
# stats = requests.get(
#     f"https://sports.core.api.espn.com/v2/sports/mma/leagues/ufc/events/600058854/competitions/401863575"
# ).json()

# %%
stats
# Out:
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/mma/leagues/ufc/events/600058854/competitions/401863575?lang=en&region=us',
#  'id': '401863575',
#  'guid': '035122ba-2eb7-3554-ac1e-1b537c80dd07',
#  'uid': 's:3301~l:3321~e:600058854~c:401863575',
#  'description': '5 Rnd (5-5-5-5-5)',
#  'date': '2026-06-15T00:00Z',
#  'endDate': '2026-06-15T00:00Z',
#  'lastUpdated': '2026-06-15T03:45Z',
#  'type': {'id': '986', 'text': 'Lightweight', 'abbreviation': 'Lightweight'},
#  'types': [{'id': '382', 'text': 'UFC Lightweight Title'}],
#  'timeValid': True,
#  'neutralSite': False,
#  'previewAvailable': False,
#  'recapAvailable': False,
#  'boxscoreAvailable': True,
#  'lineupAvailable': False,
#  'gamecastAvailable': True,
#  'playByPlayAvailable': True,
#  'conversationAvailable': True,
#  'commentaryAvailable': False,
#  'pickcenterAvailable': False,
#  'summaryAvailable': True,
#  'liveAvailable': False,
#  'ticketsAvailable': False,
#  'shotChartAvailable': False,
# ...

# %%
competition_id = "401234567"

stats2 = requests.get(
    f"https://sports.core.api.espn.com/v2/sports/mma/leagues/ufc/scorecard"
)

# %%
stats2.json()
# Out:
# {'error': {'message': 'application error', 'code': 404}}

# %%
import requests
from pprint import pprint

event_id = "600058854"

data = requests.get(
    "https://site.api.espn.com/apis/site/v2/sports/mma/ufc/scorecard",
    params={"event": event_id},
).json()

pprint(data.keys())
# Out:
# dict_keys(['code'])

# %%
data
# Out:
# {'code': 404}

# %%
resp = requests.get(
    f"https://site.web.api.espn.com/apis/common/v3/sports/mma/ufc/athletes/3022345/overview"
)

data = resp.json()

# %%
data
# Out:
# {'news': [{'headline': "MMA best of 2026 midyear: Gaethje's title victory earns three awards",
#    'lastModified': '2026-06-29T14:47:39.000+00:00',
#    'root': 'mma',
#    'premium': False,
#    'links': {'api': {'self': {'href': 'https://content.core.api.espn.com/v1/sports/news/49210990'}},
#     'mobile': {'href': 'http://m.espn.go.com/extra/mma/story?storyId=49210990'},
#     'web': {'href': 'https://www.espn.com/mma/story/_/id/49210990/mma-2026-midyear-awards-justin-gaethje-ufc-lightweight-title-victory-earns-three-awards'}},
#    'type': 'Story',
#    'section': 'MMA',
#    'id': 49210990,
#    'linkText': 'MMA 2026 midyear awards: Which event bested UFC Freedom 250?',
#    'categorized': '2026-06-29T14:47:41Z',
#    'description': 'Viable candidates for fight, knockout and submission of the year have emerged before July.',
#    'nowId': '1-49210990',
#    'allowComments': True,
#    'images': [{'width': 1296,
#      'height': 729,
# ...
